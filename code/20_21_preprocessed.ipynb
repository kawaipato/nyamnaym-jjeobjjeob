# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 필요한 변수
# - age, sex, HE_LDL_drct, HE_HDL_st2, HE_insulin, HE_glu, HE_BMI, HE_wt, HE_wc HE_chol, HE_TG

# %%
df_2020 = pd.read_csv('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/raw data/2020년 건강검진조사.csv',encoding='cp949')
df_2021 = pd.read_csv('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/raw data/2021년 건강검진조사.csv',encoding='cp949')

display(df_2020)
display(df_2021)
# Out:
# /var/folders/qr/778czgkd1p7ch8wn4f6dmdkh0000gn/T/ipykernel_81776/916277226.py:1: DtypeWarning: Columns (140,208,317,376,496,506,518,665) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2020 = pd.read_csv('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/raw data/2020년 건강검진조사.csv',encoding='cp949')
# /var/folders/qr/778czgkd1p7ch8wn4f6dmdkh0000gn/T/ipykernel_81776/916277226.py:2: DtypeWarning: Columns (140,260,285,311,380,513,662,673) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.read_csv('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/raw data/2021년 건강검진조사.csv',encoding='cp949')
#             mod_d          ID    ID_fam  year  region  town_t  apt_t   psu  \
# 0     2023.07.11.  A801169401  A8011694  2020       1       1      2  A801
# 1     2023.07.11.  A801169402  A8011694  2020       1       1      2  A801
# 2     2023.07.11.  A801169403  A8011694  2020       1       1      2  A801
# ...

# %%
for i in df_2020.columns:
    print(i)
# Out:
# mod_d
# ID
# ID_fam
# year
# region
# town_t
# apt_t
# psu
# sex
# age
# age_month
# incm
# ho_incm
# incm5
# ho_incm5
# edu
# occp
# wt_hs
# wt_itvex
# wt_oe
# wt_ntr
# wt_tot
# wt_oent
# kstrata
# cfam
# genertn
# allownc
# house
# live_t
# ainc_unit1
# ainc_1
# ainc
# marri_1
# marri_2
# fam_rela
# tins
# npins
# ID_F
# ID_M
# D_1_1
# D_2_1
# D_2_wk
# DI1_dg
# DI1_ag
# DI1_pr
# DI1_pt
# DI1_2
# DI2_dg
# DI2_ag
# DI2_pr
# DI2_pt
# DI2_2
# DI3_dg
# DI3_ag
# DI3_pr
# DI3_pt
# DI3_2
# DI4_dg
# DI4_pr
# DI4_pt
# DI5_dg
# DI5_ag
# DI5_pr
# DI5_pt
# DI6_dg
# DI6_ag
# DI6_pr
# DI6_pt
# DM1_dg
# DM1_pr
# DM1_pt
# DM2_dg
# DM2_ag
# DM2_pr
# DM2_pt
# DM3_dg
# DM3_ag
# DM3_pr
# DM3_pt
# DM4_dg
# DM4_ag
# DM4_pr
# DM4_pt
# DJ2_dg
# DJ2_ag
# DJ2_pr
# DJ2_pt
# DJ4_dg
# DJ4_ag
# DJ4_pr
# DJ4_pt
# DJ4_3
# DE2_dg
# DE2_ag
# DE2_pr
# DE2_pt
# DE1_dg
# DE1_ag
# DE1_pr
# DE1_pt
# DE1_3
# DE1_31
# DE1_32
# DE1_33
# DE1_34
# DE1_35
# DE1_4
# DC1_dg
# DC1_ag
# DC1_pr
# DC1_pt
# DC2_dg
# DC2_ag
# DC2_pr
# ...

# %%
df_2020d = df_2020[['age', 'sex', 'HE_LDL_drct', 'HE_HDL_st2', 'HE_insulin', 'HE_glu', 'HE_BMI', 'HE_wt', 'HE_wc', 'HE_chol', 'HE_TG','HE_DM_HbA1c']]
df_2021d = df_2021[['age', 'sex', 'HE_LDL_drct', 'HE_HDL_st2', 'HE_insulin', 'HE_glu', 'HE_BMI', 'HE_wt', 'HE_wc', 'HE_chol', 'HE_TG','HE_DM_HbA1c']]

# %% [markdown]
# #### 2020년도 전처리

# %%
df_2020d.isnull().sum()
# Out:
# age               0
# sex               0
# HE_LDL_drct    6515
# HE_HDL_st2     1023
# HE_insulin     1025
# HE_glu         1023
# HE_BMI          370
# HE_wt           292
# HE_wc           603
# HE_chol        1023
# HE_TG          1023
# dtype: int64

# %%
# LDL행의 HE_wt(체중), HE_BMI(체질량지수), HE_wc(허리둘레) na값 존재
df_20_drop = df_2020d[df_2020d['HE_LDL_drct'].notnull()]
print(df_20_drop.shape)
df_20_drop.isnull().sum()
# Out:
# (844, 11)
# age             0
# sex             0
# HE_LDL_drct     0
# HE_HDL_st2      0
# HE_insulin      0
# HE_glu          0
# HE_BMI         11
# HE_wt           4
# HE_wc           6
# HE_chol         0
# HE_TG           0
# dtype: int64

# %%
df_20_drop.dropna(inplace=True)
df_20_drop
# Out:
# /var/folders/qr/778czgkd1p7ch8wn4f6dmdkh0000gn/T/ipykernel_81776/3355301887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_20_drop.dropna(inplace=True)
#       age  sex  HE_LDL_drct  HE_HDL_st2  HE_insulin  HE_glu  HE_BMI  HE_wt  \
# 17     47    2        146.0        43.0        10.0   102.0    27.0   70.0
# 25     60    1         97.0        43.0        10.0    96.0    25.0   70.0
# 44     64    1         95.0        40.0         4.0    89.0    27.0   84.0
# 50     58    1        113.0        41.0        14.0   101.0    26.0   78.0
# 53     31    1         90.0        43.0        14.0    97.0    32.0  101.0
# ...   ...  ...          ...         ...         ...     ...     ...    ...
# 7333   45    1        147.0        51.0         7.0    90.0    27.0   76.0
# ...

# %% [markdown]
# #### 2021년도 전처리

# %%
df_2021d.isnull().sum()
# Out:
# age               0
# sex               0
# HE_LDL_drct    6387
# HE_HDL_st2     1073
# HE_insulin     1073
# HE_glu         1073
# HE_BMI          486
# HE_wt           404
# HE_wc           661
# HE_chol        1073
# HE_TG          1073
# dtype: int64

# %%
df_2021d[df_2021d['HE_LDL_drct'].notnull()]
# Out:
#       age  sex  HE_LDL_drct  HE_HDL_st2  HE_insulin  HE_glu  HE_BMI  HE_wt  \
# 0      61    1         96.0        61.0        28.0   103.0    27.0   87.0
# 6      77    2        152.0        49.0        13.0   101.0    21.0   52.0
# 9      49    1        108.0        35.0        11.0   171.0    28.0   90.0
# 13     57    2        103.0        39.0        19.0   117.0     NaN   66.0
# 14     69    1        123.0        52.0         8.0    96.0    28.0   72.0
# ...   ...  ...          ...         ...         ...     ...     ...    ...
# 7063   47    1        146.0        36.0        10.0   116.0    24.0   67.0
# 7069   79    2         76.0        40.0        10.0   117.0    24.0   50.0
# 7074   50    1        127.0        40.0        21.0   100.0    24.0   73.0
# 7077   43    1        163.0        42.0        10.0    98.0    24.0   70.0
# 7086   45    1        152.0        37.0        21.0   115.0    34.0  105.0
#
#       HE_wc  HE_chol  HE_TG
# 0     104.0    191.0  302.0
# ...

# %%
df_2021d[df_2021d['HE_HDL_st2'].notnull()]
# null이 아닌 HDL의 데이터가 LDL보단 많음
# Out:
#       age  sex  HE_LDL_drct  HE_HDL_st2  HE_insulin  HE_glu  HE_BMI  HE_wt  \
# 0      61    1         96.0        61.0        28.0   103.0    27.0   87.0
# 1      57    1          NaN        49.0        10.0    94.0    26.0   82.0
# 2      39    2          NaN        45.0        12.0   101.0    23.0   59.0
# 3      19    2          NaN        41.0         8.0    95.0    22.0   63.0
# 4      70    1          NaN        51.0         2.0   100.0    19.0   56.0
# ...   ...  ...          ...         ...         ...     ...     ...    ...
# 7082   44    2          NaN        35.0         9.0    99.0    24.0   60.0
# 7084   54    2          NaN        33.0         5.0    86.0    23.0   55.0
# 7085   25    1          NaN        63.0         6.0    81.0    28.0   87.0
# 7086   45    1        152.0        37.0        21.0   115.0    34.0  105.0
# 7087   43    2          NaN        56.0         3.0    78.0    20.0   55.0
#
#       HE_wc  HE_chol  HE_TG
# 0     104.0    191.0  302.0
# ...

# %%
df_21_drop = df_2021d.dropna()
print(df_21_drop.shape)
df_21_drop.isnull().sum()
# Out:
# (680, 11)
# age            0
# sex            0
# HE_LDL_drct    0
# HE_HDL_st2     0
# HE_insulin     0
# HE_glu         0
# HE_BMI         0
# HE_wt          0
# HE_wc          0
# HE_chol        0
# HE_TG          0
# dtype: int64

# %% [markdown]
# ## 전처리 후, 합치기

# %%
df_20_drop['year'] = 2020
df_21_drop['year'] = 2021
# Out:
# /var/folders/qr/778czgkd1p7ch8wn4f6dmdkh0000gn/T/ipykernel_81776/3695286554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_20_drop['year'] = 2020
# /var/folders/qr/778czgkd1p7ch8wn4f6dmdkh0000gn/T/ipykernel_81776/3695286554.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_21_drop['year'] = 2021

# %%
df_20_21=pd.concat([df_20_drop,df_21_drop])
df_20_21
# Out:
#       age  sex  HE_LDL_drct  HE_HDL_st2  HE_insulin  HE_glu  HE_BMI  HE_wt  \
# 17     47    2        146.0        43.0        10.0   102.0    27.0   70.0
# 25     60    1         97.0        43.0        10.0    96.0    25.0   70.0
# 44     64    1         95.0        40.0         4.0    89.0    27.0   84.0
# 50     58    1        113.0        41.0        14.0   101.0    26.0   78.0
# 53     31    1         90.0        43.0        14.0    97.0    32.0  101.0
# ...   ...  ...          ...         ...         ...     ...     ...    ...
# 7063   47    1        146.0        36.0        10.0   116.0    24.0   67.0
# 7069   79    2         76.0        40.0        10.0   117.0    24.0   50.0
# 7074   50    1        127.0        40.0        21.0   100.0    24.0   73.0
# 7077   43    1        163.0        42.0        10.0    98.0    24.0   70.0
# 7086   45    1        152.0        37.0        21.0   115.0    34.0  105.0
#
#       HE_wc  HE_chol  HE_TG  year
# ...

# %%
df_20_21.to_csv('20_21_data.csv',encoding='cp949')

# %%
df_20_21_drop = pd.concat([df_2020d,df_2021d])
df_20_21_drop.to_csv('df_20_21_drop.csv',encoding='cp949')

# %% [markdown]
# ### 모든 데이터 na값 제거 안하고

# %%
import os
os.getcwd()
# Out:
# '/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/code'

# %%
file_list = os.listdir('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/data/raw_data')
file_list_py = [file for file in file_list if file.endswith('.csv')]
file_list_py
# Out:
# ['2020년 건강검진조사.csv',
#  '2015년 건강검진조사.csv',
#  '2009년 건강검진조사.csv',
#  '2019년 건강검진조사.csv',
#  '2007년 건강검진조사.csv',
#  '2008년 건강검진조사.csv',
#  '2010년 건강검진조사.csv',
#  '2021년 건강검진조사.csv']

# %%
df_2007 = pd.read_csv('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/data/raw_data/2007년 건강검진조사.csv')
df_2008 = pd.read_csv('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/data/raw_data/2008년 건강검진조사.csv')
df_2019 = pd.read_csv('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/data/raw_data/2019년 건강검진조사.csv')
# Out:
# /var/folders/qr/778czgkd1p7ch8wn4f6dmdkh0000gn/T/ipykernel_81776/761801170.py:1: DtypeWarning: Columns (73,362,368,489,572,922,932,935,942,944,945,946) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2007 = pd.read_csv('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/data/raw_data/2007년 건강검진조사.csv')
# /var/folders/qr/778czgkd1p7ch8wn4f6dmdkh0000gn/T/ipykernel_81776/761801170.py:2: DtypeWarning: Columns (84,113,238,373,379,489,500,569,577,583,597,621,643,669,700,704,755,765,812,824,976,985,987,988,996,997,1112,1150) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2008 = pd.read_csv('/Users/seoihwan/Desktop/escuela/과기대/nyamnaym-jjeobjjeob/data/raw_data/2008년 건강검진조사.csv')
# /var/folders/qr/778czgkd1p7ch8wn4f6dmdkh0000gn/T/ipykernel_81776/761801170.py:3: DtypeWarning: Columns (140,208,317,376,496,506,518,665) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
df_2019d = df_2019[['age', 'sex', 'HE_LDL_drct', 'HE_HDL_st2', 'HE_insulin', 'HE_glu', 'HE_BMI', 'HE_wt', 'HE_wc', 'HE_chol', 'HE_TG','HE_DM_HbA1c']]

# %%
df_192021 = pd.concat([df_2019d,df_2020d,df_2021d])
df_192021
# Out:
#       age  sex  HE_LDL_drct  HE_HDL_st2  HE_insulin  HE_glu  HE_BMI  HE_wt  \
# 0      39    1          NaN        44.0         5.0    84.0    24.0   78.0
# 1      39    2          NaN        65.0         4.0    89.0    18.0   53.0
# 2      10    1          NaN        66.0         4.0    90.0    14.0   27.0
# 3       7    1          NaN         NaN         NaN     NaN    17.0   28.0
# 4       4    1          NaN         NaN         NaN     NaN    14.0   17.0
# ...   ...  ...          ...         ...         ...     ...     ...    ...
# 7085   25    1          NaN        63.0         6.0    81.0    28.0   87.0
# 7086   45    1        152.0        37.0        21.0   115.0    34.0  105.0
# 7087   43    2          NaN        56.0         3.0    78.0    20.0   55.0
# 7088    8    1          NaN         NaN         NaN     NaN    16.0   28.0
# 7089    8    1          NaN         NaN         NaN     NaN    17.0   31.0
#
#       HE_wc  HE_chol  HE_TG  HE_DM_HbA1c
# ...

# %%
df_192021.isnull().sum()
# Out:
# age                0
# sex                0
# HE_LDL_drct    19417
# HE_HDL_st2      3119
# HE_insulin      3123
# HE_glu          3119
# HE_BMI          1226
# HE_wt            988
# HE_wc           1867
# HE_chol         3119
# HE_TG           3119
# HE_DM_HbA1c     5237
# dtype: int64

# %%
df_192021.to_csv('df_192021.csv',encoding='cp949')

# %%
df_2007d = df_2007[['age', 'sex', 'HE_HDL_st2', 'HE_insulin', 'HE_glu', 'HE_BMI', 'HE_wt', 'HE_wc', 'HE_chol', 'HE_TG']]
df_2008d = df_2008[['age', 'sex', 'HE_HDL_st2', 'HE_insulin', 'HE_glu', 'HE_BMI', 'HE_wt', 'HE_wc', 'HE_chol', 'HE_TG']]

# %%
df_2007d.to_csv('df_2007.csv',encoding='cp949')
df_2008d.to_csv('df_2008.csv',encoding='cp949')
